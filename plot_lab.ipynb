# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[5,7,4,3,1]
color=['red','black','peru','orchid','deepskyblue']
xLabel=['pop','classic','pure','blue','electronic']
plt.xticks(x, xLabel)
plt.bar(x,y,color=color)
# Out:
# <BarContainer object of 5 artists>
